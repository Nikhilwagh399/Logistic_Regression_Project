# %%
 ## Importing the necessary libraries

import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
df = pd.read_csv('healthcare-dataset-stroke-data (1).csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.shape
# Out:
# (5110, 12)

# %% [markdown]
# ## 5110 patients data, 12 column, test checkups,
# ## Problem statement
# * they want to build a ML model(Logistic regression) which will predict whether person will get stroke attack or not

# %%
#Target - Stroke

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# this is encodeed data 
# 1 - stroke- yes
# 0 - stroke - no

# %%
df['stroke'].value_counts()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
#based on the gener will see the stroke ka countplot

# %%
sns.countplot(x = 'stroke', hue = 'gender' , data = df, palette = 'Set1')
# Out:
# <Axes: xlabel='stroke', ylabel='count'>

# %%
# Violin plot

# %%
#split by gender and age
sns.violinplot(x = 'stroke' , y = 'age', hue = 'gender', data  = df , palette = 'Set1')
# Out:
# <Axes: xlabel='stroke', ylabel='age'>

# %%
sns.boxplot(df['stroke'])
# Out:
# <Axes: ylabel='stroke'>

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x = 'stroke' , y = 'bmi', hue = 'gender' , data = df , palette = 'winter')
plt.title('BMIs')
plt.show()

# %%
#Coutplot to check the occurence of stroke across rural and urban areas

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
sns.countplot(x = 'stroke' , hue = 'Residence_type' , data = df , palette = 'GnBu')
plt.title('Resident Type')
plt.show()

# %%
#count plot to check the occurence of stroke by marital status

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
sns.countplot(x = 'heart_disease' , hue = 'stroke' , data = df)
plt.title('Heart Condition')
plt.show()

# %%
#heart disease - no heart disease
# hear dis - yes - heart disease

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# count plot to check the occurence of stroke by occupation

# %%
sns.countplot(x = 'work_type' , hue  = 'stroke' , data = df)
plt.title('Occupation')
plt.show()

# %% [markdown]
# ## countplot to check subjects with/without blood sugar and stroke
# * sns.countplot(x = 'avg_glucose_level' , hue = 'stroke' , data = df) plt.title('Blood Glucose Level') plt.show()

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## Feature engineering

# %%
#encoding-work type

# %%
residence = pd.get_dummies(df['Residence_type'] , drop_first = True)

# %%
residence #one-hot encoding
# Out:
#       Urban
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# ...     ...
# 5105   True
# 5106   True
# 5107  False
# 5108  False
# 5109   True
#
# [5110 rows x 1 columns]

# %%
df1 = pd.concat([df,residence],  axis = 1)

# %%
df1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  Urban
# 0       1   True
# 1       1  False
# 2       1  False
# 3       1   True
# 4       1  False

# %%
df1.drop(['Residence_type'] , axis = 1, inplace = True)

# %%
df1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type  avg_glucose_level   bmi   smoking_status  stroke  Urban
# 0        Private             228.69  36.6  formerly smoked       1   True
# 1  Self-employed             202.21   NaN     never smoked       1  False
# 2        Private             105.92  32.5     never smoked       1  False
# 3        Private             171.23  34.4           smokes       1   True
# 4  Self-employed             174.12  24.0     never smoked       1  False

# %%
sex = pd.get_dummies(df['gender'] , drop_first = True)
df2 = pd.concat([df1, sex],  axis = 1)
df2.drop(['gender'] , axis = 1, inplace = True)

# %%
df2 = pd.concat([df1, sex],  axis = 1)
df2.drop(['gender'] , axis = 1, inplace = True)

# %%
df2.head()
# Out:
#       id   age  hypertension  heart_disease ever_married      work_type  \
# 0   9046  67.0             0              1          Yes        Private
# 1  51676  61.0             0              0          Yes  Self-employed
# 2  31112  80.0             0              1          Yes        Private
# 3  60182  49.0             0              0          Yes        Private
# 4   1665  79.0             1              0          Yes  Self-employed
#
#    avg_glucose_level   bmi   smoking_status  stroke  Urban   Male  Other
# 0             228.69  36.6  formerly smoked       1   True   True  False
# 1             202.21   NaN     never smoked       1  False  False  False
# 2             105.92  32.5     never smoked       1  False   True  False
# 3             171.23  34.4           smokes       1   True  False  False
# 4             174.12  24.0     never smoked       1  False  False  False

# %%
martial_status = pd.get_dummies(df['ever_married'])

# %%
martial_status
# Out:
#          No   Yes
# 0     False  True
# 1     False  True
# 2     False  True
# 3     False  True
# 4     False  True
# ...     ...   ...
# 5105  False  True
# 5106  False  True
# 5107  False  True
# 5108  False  True
# 5109  False  True
#
# [5110 rows x 2 columns]

# %%
df2.drop(['ever_married'], axis =1 , inplace = True)

# %%
df3 = pd.concat([df2 , martial_status] , axis = 1)

# %%
df3.head()
# Out:
#       id   age  hypertension  heart_disease      work_type  avg_glucose_level  \
# 0   9046  67.0             0              1        Private             228.69
# 1  51676  61.0             0              0  Self-employed             202.21
# 2  31112  80.0             0              1        Private             105.92
# 3  60182  49.0             0              0        Private             171.23
# 4   1665  79.0             1              0  Self-employed             174.12
#
#     bmi   smoking_status  stroke  Urban   Male  Other     No   Yes
# 0  36.6  formerly smoked       1   True   True  False  False  True
# 1   NaN     never smoked       1  False  False  False  False  True
# 2  32.5     never smoked       1  False   True  False  False  True
# 3  34.4           smokes       1   True  False  False  False  True
# 4  24.0     never smoked       1  False  False  False  False  True

# %%
smoking = pd.get_dummies(df2['smoking_status'], drop_first = True)

# %%
smoking
# Out:
#       formerly smoked  never smoked  smokes
# 0                True         False   False
# 1               False          True   False
# 2               False          True   False
# 3               False         False    True
# 4               False          True   False
# ...               ...           ...     ...
# 5105            False          True   False
# 5106            False          True   False
# 5107            False          True   False
# 5108             True         False   False
# 5109            False         False   False
#
# [5110 rows x 3 columns]

# %%
df3.drop(['smoking_status'], axis =1 , inplace = True)
df4 = pd.concat([df3 , smoking ] , axis = 1)

# %%
df4.head()
# Out:
#       id   age  hypertension  heart_disease      work_type  avg_glucose_level  \
# 0   9046  67.0             0              1        Private             228.69
# 1  51676  61.0             0              0  Self-employed             202.21
# 2  31112  80.0             0              1        Private             105.92
# 3  60182  49.0             0              0        Private             171.23
# 4   1665  79.0             1              0  Self-employed             174.12
#
#     bmi  stroke  Urban   Male  Other     No   Yes  formerly smoked  \
# 0  36.6       1   True   True  False  False  True             True
# 1   NaN       1  False  False  False  False  True            False
# 2  32.5       1  False   True  False  False  True            False
# 3  34.4       1   True  False  False  False  True            False
# 4  24.0       1  False  False  False  False  True            False
#
#    never smoked  smokes
# 0         False   False
# 1          True   False
# 2          True   False
# 3         False    True
# 4          True   False

# %%
working = pd.get_dummies(df3['work_type'], drop_first = True)

# %%
working
# Out:
#       Never_worked  Private  Self-employed  children
# 0            False     True          False     False
# 1            False    False           True     False
# 2            False     True          False     False
# 3            False     True          False     False
# 4            False    False           True     False
# ...            ...      ...            ...       ...
# 5105         False     True          False     False
# 5106         False    False           True     False
# 5107         False    False           True     False
# 5108         False     True          False     False
# 5109         False    False          False     False
#
# [5110 rows x 4 columns]

# %%
df3.drop(['work_type'], axis =1 , inplace = True)
df5 = pd.concat([df4 , working ] , axis = 1)

# %%
df5.drop(['work_type'], axis =1 , inplace = True)

# %%
df5.head()
# Out:
#       id   age  hypertension  heart_disease  avg_glucose_level   bmi  stroke  \
# 0   9046  67.0             0              1             228.69  36.6       1
# 1  51676  61.0             0              0             202.21   NaN       1
# 2  31112  80.0             0              1             105.92  32.5       1
# 3  60182  49.0             0              0             171.23  34.4       1
# 4   1665  79.0             1              0             174.12  24.0       1
#
#    Urban   Male  Other     No   Yes  formerly smoked  never smoked  smokes  \
# 0   True   True  False  False  True             True         False   False
# 1  False  False  False  False  True            False          True   False
# 2  False   True  False  False  True            False          True   False
# 3   True  False  False  False  True            False         False    True
# 4  False  False  False  False  True            False          True   False
#
#    Never_worked  Private  Self-employed  children
# 0         False     True          False     False
# 1         False    False           True     False
# 2         False     True          False     False
# 3         False     True          False     False
# 4         False    False           True     False

# %%
from sklearn.model_selection import train_test_split

# %%
df5.drop(['id'] , axis =1 , inplace = True)

# %%
df5.dropna(inplace = True) #drop the null values

# %%
df5.isna().sum()
# Out:
# age                  0
# hypertension         0
# heart_disease        0
# avg_glucose_level    0
# bmi                  0
# stroke               0
# Urban                0
# Male                 0
# Other                0
# No                   0
# Yes                  0
# formerly smoked      0
# never smoked         0
# smokes               0
# Never_worked         0
# Private              0
# Self-employed        0
# children             0
# dtype: int64

# %%
#x = independent varibles
X = df5.drop('stroke' , axis = 1)

# %%
X.head()
# Out:
#     age  hypertension  heart_disease  avg_glucose_level   bmi  Urban   Male  \
# 0  67.0             0              1             228.69  36.6   True   True
# 2  80.0             0              1             105.92  32.5  False   True
# 3  49.0             0              0             171.23  34.4   True  False
# 4  79.0             1              0             174.12  24.0  False  False
# 5  81.0             0              0             186.21  29.0   True   True
#
#    Other     No   Yes  formerly smoked  never smoked  smokes  Never_worked  \
# 0  False  False  True             True         False   False         False
# 2  False  False  True            False          True   False         False
# 3  False  False  True            False         False    True         False
# 4  False  False  True            False          True   False         False
# 5  False  False  True             True         False   False         False
#
#    Private  Self-employed  children
# 0     True          False     False
# 2     True          False     False
# 3     True          False     False
# 4    False           True     False
# 5     True          False     False

# %%
y = df5['stroke']
#y - Target varibleal

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\nikhi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
#model evaluation

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1412
#            1       0.00      0.00      0.00        61
#
#     accuracy                           0.96      1473
#    macro avg       0.48      0.50      0.49      1473
# weighted avg       0.92      0.96      0.94      1473
# C:\Users\nikhi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\nikhi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\nikhi\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
model.score(X_test, y_test)
# Out:
# 0.9585879158180584

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred) #really great accuracy
# Out:
# 0.9585879158180584

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[1412    0]
#  [  61    0]]

# %%
sns.heatmap(confusion_matrix(y_test, y_pred) , annot = True , cmap = 'viridis', fmt = '2' )
plt.title('Confusion Matrix')
plt.show()
